# %% [markdown]
# ## Train a model with bike rental data using XGBoost algorithm
# ###  Model is trained with XGBoost installed in notebook instance
# ###  In the later examples, we will train using SageMaker's XGBoost algorithm

# %%
# Install xgboost in notebook instance.
#### Command to install xgboost
# !conda install -y -c conda-forge xgboost

# %%
# %matplotlib inline
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb

# %%
column_list_file = 'bike_train_column_list.txt'
train_file = 'bike_train.csv'
validation_file = 'bike_validation.csv'
test_file = 'bike_test.csv'

# %%
columns = ''
with open(column_list_file,'r') as f:
    columns = f.read().split(',')

# %%
columns
# Out:
# ['count',
#  'season',
#  'holiday',
#  'workingday',
#  'weather',
#  'temp',
#  'atemp',
#  'humidity',
#  'windspeed',
#  'year',
#  'month',
#  'day',
#  'dayofweek',
#  'hour']

# %%
# Specify the column names as the file does not have column header
df_train = pd.read_csv(train_file,names=columns)
df_validation = pd.read_csv(validation_file,names=columns)

# %%
df_train.head()
# Out:
#    count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 0     87       3        0           0        2  26.24  30.305        73
# 1    248       3        0           1        1  32.80  34.850        33
# 2    334       4        0           0        1  15.58  19.695        40
# 3    623       3        0           1        1  32.80  37.880        55
# 4     70       2        0           1        1  13.94  17.425        76
#
#    windspeed  year  month  day  dayofweek  hour
# 0     7.0015  2011      9    3          5     0
# 1     7.0015  2012      8   13          0    14
# 2    11.0014  2011     11    5          5    17
# 3    12.9980  2012      8    9          3    19
# 4     7.0015  2011      4   14          3     6

# %%
df_validation.head()
# Out:
#    count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 0    443       3        0           1        2  28.70  33.335        79
# 1    387       2        0           0        1  32.80  37.880        55
# 2      2       1        0           1        1  14.76  16.665        40
# 3     48       1        0           1        1   9.02   9.090        47
# 4     55       4        0           0        1  10.66  15.150        87
#
#    windspeed  year  month  day  dayofweek  hour
# 0    12.9980  2011      7    7          3     8
# 1    12.9980  2011      6   11          5    13
# 2    19.9995  2011      2   14          0     2
# 3    36.9974  2011      2    8          1    10
# 4     0.0000  2011     12    4          6     8

# %%
X_train = df_train.iloc[:,1:] # Features: 1st column onwards 
y_train = df_train.iloc[:,0].ravel() # Target: 0th column

X_validation = df_validation.iloc[:,1:]
y_validation = df_validation.iloc[:,0].ravel()

# %%
# XGBoost Training Parameter Reference: 
#   https://github.com/dmlc/xgboost/blob/master/doc/parameter.md
regressor = xgb.XGBRegressor(max_depth=5,eta=0.1,subsample=0.7,num_round=150)

# %%
regressor
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, eta=0.1, gamma=0, learning_rate=0.1,
#        max_delta_step=0, max_depth=5, min_child_weight=1, missing=None,
#        n_estimators=100, n_jobs=1, nthread=None, num_round=150,
#        objective='reg:linear', random_state=0, reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=None, silent=True, subsample=0.7)

# %%
regressor.fit(X_train,y_train, eval_set = [(X_train, y_train), (X_validation, y_validation)])
# Out:
# [0]	validation_0-rmse:242.007	validation_1-rmse:240.501
# [1]	validation_0-rmse:222.787	validation_1-rmse:221.269
# [2]	validation_0-rmse:205.625	validation_1-rmse:204.082
# [3]	validation_0-rmse:190.616	validation_1-rmse:188.98
# [4]	validation_0-rmse:177.13	validation_1-rmse:175.719
# [5]	validation_0-rmse:165.412	validation_1-rmse:164.057
# [6]	validation_0-rmse:155.155	validation_1-rmse:153.879
# [7]	validation_0-rmse:146.127	validation_1-rmse:144.913
# [8]	validation_0-rmse:137.882	validation_1-rmse:136.735
# [9]	validation_0-rmse:129.922	validation_1-rmse:128.981
# [10]	validation_0-rmse:123.095	validation_1-rmse:122.538
# [11]	validation_0-rmse:116.566	validation_1-rmse:116.245
# [12]	validation_0-rmse:111.124	validation_1-rmse:111.116
# [13]	validation_0-rmse:104.706	validation_1-rmse:105.089
# [14]	validation_0-rmse:100.904	validation_1-rmse:101.406
# [15]	validation_0-rmse:96.8297	validation_1-rmse:97.5654
# [16]	validation_0-rmse:93.7758	validation_1-rmse:94.5013
# [17]	validation_0-rmse:89.5102	validation_1-rmse:90.5583
# [18]	validation_0-rmse:85.9746	validation_1-rmse:87.1458
# [19]	validation_0-rmse:82.976	validation_1-rmse:84.3359
# [20]	validation_0-rmse:79.6549	validation_1-rmse:81.2047
# [21]	validation_0-rmse:76.6105	validation_1-rmse:78.4359
# [22]	validation_0-rmse:72.5117	validation_1-rmse:74.6515
# [23]	validation_0-rmse:70.9521	validation_1-rmse:73.2255
# [24]	validation_0-rmse:68.8014	validation_1-rmse:71.2041
# [25]	validation_0-rmse:67.5695	validation_1-rmse:70.0069
# [26]	validation_0-rmse:64.9883	validation_1-rmse:67.6766
# [27]	validation_0-rmse:63.5887	validation_1-rmse:66.4121
# [28]	validation_0-rmse:62.594	validation_1-rmse:65.5449
# [29]	validation_0-rmse:61.3974	validation_1-rmse:64.4172
# [30]	validation_0-rmse:58.9778	validation_1-rmse:62.2073
# [31]	validation_0-rmse:58.2745	validation_1-rmse:61.6184
# [32]	validation_0-rmse:56.4789	validation_1-rmse:59.9935
# [33]	validation_0-rmse:55.511	validation_1-rmse:59.1177
# [34]	validation_0-rmse:54.9497	validation_1-rmse:58.6167
# [35]	validation_0-rmse:54.4688	validation_1-rmse:58.1837
# [36]	validation_0-rmse:53.9773	validation_1-rmse:57.7184
# [37]	validation_0-rmse:53.3147	validation_1-rmse:57.0953
# [38]	validation_0-rmse:53.0139	validation_1-rmse:56.7813
# [39]	validation_0-rmse:52.6673	validation_1-rmse:56.4665
# [40]	validation_0-rmse:51.7864	validation_1-rmse:55.6969
# [41]	validation_0-rmse:51.4528	validation_1-rmse:55.4159
# [42]	validation_0-rmse:51.033	validation_1-rmse:55.0248
# [43]	validation_0-rmse:49.7943	validation_1-rmse:53.8954
# [44]	validation_0-rmse:49.3368	validation_1-rmse:53.5101
# [45]	validation_0-rmse:48.3301	validation_1-rmse:52.6475
# [46]	validation_0-rmse:48.091	validation_1-rmse:52.4331
# [47]	validation_0-rmse:47.1916	validation_1-rmse:51.6484
# [48]	validation_0-rmse:46.9418	validation_1-rmse:51.4275
# [49]	validation_0-rmse:46.6992	validation_1-rmse:51.2146
# [50]	validation_0-rmse:46.2508	validation_1-rmse:50.7437
# [51]	validation_0-rmse:45.4183	validation_1-rmse:49.9671
# [52]	validation_0-rmse:45.2	validation_1-rmse:49.8055
# [53]	validation_0-rmse:44.5792	validation_1-rmse:49.2526
# [54]	validation_0-rmse:44.4954	validation_1-rmse:49.1649
# [55]	validation_0-rmse:44.2448	validation_1-rmse:48.9718
# [56]	validation_0-rmse:43.9678	validation_1-rmse:48.8024
# [57]	validation_0-rmse:43.7825	validation_1-rmse:48.7015
# [58]	validation_0-rmse:43.4615	validation_1-rmse:48.4276
# [59]	validation_0-rmse:43.3009	validation_1-rmse:48.3417
# [60]	validation_0-rmse:42.8066	validation_1-rmse:47.9228
# [61]	validation_0-rmse:42.6113	validation_1-rmse:47.8314
# [62]	validation_0-rmse:42.3148	validation_1-rmse:47.5211
# [63]	validation_0-rmse:42.2306	validation_1-rmse:47.4275
# [64]	validation_0-rmse:42.1452	validation_1-rmse:47.3608
# [65]	validation_0-rmse:41.8505	validation_1-rmse:47.0969
# [66]	validation_0-rmse:41.7405	validation_1-rmse:46.9939
# [67]	validation_0-rmse:41.4812	validation_1-rmse:46.814
# [68]	validation_0-rmse:41.2688	validation_1-rmse:46.6438
# [69]	validation_0-rmse:41.1858	validation_1-rmse:46.5998
# [70]	validation_0-rmse:41.0853	validation_1-rmse:46.5623
# [71]	validation_0-rmse:41.0028	validation_1-rmse:46.48
# [72]	validation_0-rmse:40.9	validation_1-rmse:46.373
# [73]	validation_0-rmse:40.4973	validation_1-rmse:45.9951
# [74]	validation_0-rmse:40.333	validation_1-rmse:45.8647
# [75]	validation_0-rmse:40.1839	validation_1-rmse:45.6938
# [76]	validation_0-rmse:39.8168	validation_1-rmse:45.4183
# [77]	validation_0-rmse:39.3876	validation_1-rmse:45.0351
# [78]	validation_0-rmse:39.273	validation_1-rmse:44.9556
# [79]	validation_0-rmse:39.1868	validation_1-rmse:44.8942
# [80]	validation_0-rmse:39.1003	validation_1-rmse:44.8636
# [81]	validation_0-rmse:39.0267	validation_1-rmse:44.8348
# [82]	validation_0-rmse:38.8835	validation_1-rmse:44.7191
# [83]	validation_0-rmse:38.6657	validation_1-rmse:44.5271
# [84]	validation_0-rmse:38.5294	validation_1-rmse:44.437
# [85]	validation_0-rmse:38.3248	validation_1-rmse:44.2871
# [86]	validation_0-rmse:38.172	validation_1-rmse:44.135
# [87]	validation_0-rmse:38.0034	validation_1-rmse:43.9956
# [88]	validation_0-rmse:37.9063	validation_1-rmse:43.9513
# [89]	validation_0-rmse:37.7576	validation_1-rmse:43.8912
# [90]	validation_0-rmse:37.7327	validation_1-rmse:43.8913
# [91]	validation_0-rmse:37.6295	validation_1-rmse:43.8137
# [92]	validation_0-rmse:37.4694	validation_1-rmse:43.7091
# [93]	validation_0-rmse:37.3759	validation_1-rmse:43.6424
# [94]	validation_0-rmse:37.1929	validation_1-rmse:43.5612
# [95]	validation_0-rmse:36.937	validation_1-rmse:43.3541
# [96]	validation_0-rmse:36.7666	validation_1-rmse:43.219
# [97]	validation_0-rmse:36.6528	validation_1-rmse:43.1459
# [98]	validation_0-rmse:36.5781	validation_1-rmse:43.1037
# [99]	validation_0-rmse:36.4366	validation_1-rmse:43.0051
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, eta=0.1, gamma=0, learning_rate=0.1,
#        max_delta_step=0, max_depth=5, min_child_weight=1, missing=None,
#        n_estimators=100, n_jobs=1, nthread=None, num_round=150,
#        objective='reg:linear', random_state=0, reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=None, silent=True, subsample=0.7)

# %%
eval_result = regressor.evals_result()

# %%
training_rounds = range(len(eval_result['validation_0']['rmse']))

# %%
print(training_rounds)
# Out:
# range(0, 100)

# %%
plt.scatter(x=training_rounds,y=eval_result['validation_0']['rmse'],label='Training Error')
plt.scatter(x=training_rounds,y=eval_result['validation_1']['rmse'],label='Validation Error')
plt.grid(True)
plt.xlabel('Input Feature')
plt.ylabel('RMSE')
plt.title('Training Vs Validation Error')
plt.legend()

# %%
xgb.plot_importance(regressor)

# %%
df = pd.read_csv('bike_all.csv')

# %%
df.head()
# Out:
#    count  season  holiday  workingday  weather  temp   atemp  humidity  \
# 0     16       1        0           0        1  9.84  14.395        81
# 1     40       1        0           0        1  9.02  13.635        80
# 2     32       1        0           0        1  9.02  13.635        80
# 3     13       1        0           0        1  9.84  14.395        75
# 4      1       1        0           0        1  9.84  14.395        75
#
#    windspeed  year  month  day  dayofweek  hour
# 0        0.0  2011      1    1          5     0
# 1        0.0  2011      1    1          5     1
# 2        0.0  2011      1    1          5     2
# 3        0.0  2011      1    1          5     3
# 4        0.0  2011      1    1          5     4

# %%
X_test = df.iloc[:,1:]
print(X_test[:5])
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    year  month  day  dayofweek  hour
# 0  2011      1    1          5     0
# 1  2011      1    1          5     1
# 2  2011      1    1          5     2
# 3  2011      1    1          5     3
# 4  2011      1    1          5     4

# %%
result = regressor.predict(X_test)

# %%
result[:5]
# Out:
# array([32.89392  , 35.87318  , 26.616594 ,  7.4038415, -3.2827568],
#       dtype=float32)

# %%
df['count_predicted'] = result

# %%
df.head()
# Out:
#    count  season  holiday  workingday  weather  temp   atemp  humidity  \
# 0     16       1        0           0        1  9.84  14.395        81
# 1     40       1        0           0        1  9.02  13.635        80
# 2     32       1        0           0        1  9.02  13.635        80
# 3     13       1        0           0        1  9.84  14.395        75
# 4      1       1        0           0        1  9.84  14.395        75
#
#    windspeed  year  month  day  dayofweek  hour  count_predicted
# 0        0.0  2011      1    1          5     0        32.893921
# 1        0.0  2011      1    1          5     1        35.873180
# 2        0.0  2011      1    1          5     2        26.616594
# 3        0.0  2011      1    1          5     3         7.403841
# 4        0.0  2011      1    1          5     4        -3.282757

# %%
# Negative Values are predicted
df['count_predicted'].describe()
# Out:
# count    10886.000000
# mean       191.312378
# std        171.435974
# min        -69.783882
# 25%         41.953001
# 50%        152.628525
# 75%        286.643951
# max        868.469849
# Name: count_predicted, dtype: float64

# %%
df[df['count_predicted'] < 0]
# Out:
#        count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 4          1       1        0           0        1   9.84  14.395        75
# 5          1       1        0           0        2   9.84  12.880        75
# 6          2       1        0           0        1   9.02  13.635        80
# 7          3       1        0           0        1   8.20  12.880        86
# 18        35       1        0           0        3  17.22  21.210        88
# 19        37       1        0           0        3  17.22  21.210        88
# 28         3       1        0           0        2  18.86  22.725        94
# 29         2       1        0           0        3  17.22  21.210        77
# 30         1       1        0           0        2  16.40  20.455        76
# 44        31       1        0           0        1  10.66  11.365        44
# 45         9       1        0           0        1   9.84  10.605        44
# 46         8       1        0           0        1   9.02  11.365        47
# 48         2       1        0           1        1   8.20   8.335        44
# 49         1       1        0           1        1   6.56   6.820        47
# 70         2       1        0           1        1   6.56   9.090        59
# 71         1       1        0           1        1   5.74   7.575        63
# 72         2       1        0           1        1   5.74   9.090        63
# 94        6.0032  2011      1    5          2     2        -6.609873
# 95       15.0013  2011      1    5          2     4        -5.340166
# 116       0.0000  2011      1    6          3     1        -3.128213
# 117       0.0000  2011      1    6          3     2        -7.194346
# 118       6.0032  2011      1    6          3     4        -5.676157
# 139      15.0013  2011      1    7          4     1        -1.295940
# 140      15.0013  2011      1    7          4     2        -6.332713
# 141       8.9981  2011      1    7          4     4        -5.679472
# 142       0.0000  2011      1    7          4     5        -2.492162
# 165      11.0014  2011      1    8          5     4        -9.975814
# 166      11.0014  2011      1    8          5     5        -2.576862
# ...          ...   ...    ...  ...        ...   ...              ...
# 6166      6.0032  2012      2   13          0     4        -0.011657
# 6408     19.9995  2012      3    4          6     6        -4.702317
# 6524     27.9993  2012      3    9          4     2        -2.852100
# 6526     19.0012  2012      3    9          4     4        -5.497634
# 6619     19.9995  2012      3   13          1     2        -4.852264
# 6620     19.9995  2012      3   13          1     3        -4.852264
# 7363     11.0014  2012      5    6          6     4        -2.227806
# 7364     11.0014  2012      5    6          6     5        -1.466546
# 7365     15.0013  2012      5    6          6     6        -6.469108
# 7433     30.0026  2012      5    9          2     2        -4.506272
# 7434     11.0014  2012      5    9          2     3        -1.362004
# 7435     15.0013  2012      5    9          2     4        -2.959447
# 7578      8.9981  2012      5   15          1     3        -5.279234
# 7579      0.0000  2012      5   15          1     4        -7.790005
# 7963     11.0014  2012      6   12          1     4        -1.852657
# 8106     15.0013  2012      6   18          0     3        -3.829226
# 8323      7.0015  2012      7    8          6     4        -9.244391
# 8324      0.0000  2012      7    8          6     5       -10.961242
# 8325      8.9981  2012      7    8          6     6        -6.409223
# 8345     12.9980  2012      7    9          0     2        -4.920081
# 8346     12.9980  2012      7    9          0     3        -5.536590
# 8347     26.0027  2012      7    9          0     4       -14.809877
# 9473     12.9980  2012      9   18          1     2        -5.411341
# 9713     16.9979  2012     10    9          1     2        -6.249047
# 9714     19.0012  2012     10    9          1     3        -6.235983
# 9715     11.0014  2012     10    9          1     4        -0.701477
# 10263    43.0006  2012     11   13          1     1        -1.983871
# 10264    30.0026  2012     11   13          1     2        -3.528498
# 10265    23.9994  2012     11   13          1     3        -4.139180
# 10628     7.0015  2012     12    9          6     6        -7.529441
#
# [307 rows x 15 columns]

# %%
df['count_predicted'].hist()

# %%
def adjust_count(x):
    if x < 0:
        return 0
    else:
        return x

# %%
df['count_predicted'] = df['count_predicted'].map(adjust_count)

# %%
df[df['count_predicted'] < 0]
# Out:
# Empty DataFrame
# Columns: [count, season, holiday, workingday, weather, temp, atemp, humidity, windspeed, year, month, day, dayofweek, hour, count_predicted]
# Index: []

# %%
plt.boxplot([df['count'],df['count_predicted']], labels=['actual','predicted'])
plt.title('Box Plot - Actual, Predicted')
plt.ylabel('Target')
plt.grid(True)

# %%
# Over prediction and Under Prediction needs to be balanced
# Training Data Residuals
residuals = (df['count_predicted'] - df['count'])

plt.hist(residuals)
plt.grid(True)
plt.xlabel('(Predicted - Actual)')
plt.ylabel('Count')
plt.title('Residuals Distribution')
plt.axvline(color='g')

# %%
import sklearn.metrics as metrics
print("RMSE: {0}".format(metrics.mean_squared_error(df['count'],df['count_predicted'])**.5))
# Out:
# RMSE: 38.4592770007648

# %%
# Metric Use By Kaggle
def compute_rmsle(y_true, y_pred):
    if type(y_true) != np.ndarray:
        y_true = np.array(y_true)
        
    if type(y_pred) != np.ndarray:
        y_pred = np.array(y_pred)
     
    return(np.average((np.log1p(y_pred) - np.log1p(y_true))**2)**.5)

# %%
print("RMSLE: {0}".format(compute_rmsle(df['count'],df['count_predicted'])))
# Out:
# RMSLE: 0.4702600891438421

# %%
# Prepare Data for Submission to Kaggle
df_test = pd.read_csv(test_file,parse_dates=['datetime'])

# %%
df_test.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  day  dayofweek  hour
# 0        56    26.0027  2011      1   20          3     0
# 1        56     0.0000  2011      1   20          3     1
# 2        56     0.0000  2011      1   20          3     2
# 3        56    11.0014  2011      1   20          3     3
# 4        56    11.0014  2011      1   20          3     4

# %%
X_test =  df_test.iloc[:,1:] # Exclude datetime for prediction

# %%
X_test.head()
# Out:
#    season  holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0       1        0           1        1  10.66  11.365        56    26.0027
# 1       1        0           1        1  10.66  13.635        56     0.0000
# 2       1        0           1        1  10.66  13.635        56     0.0000
# 3       1        0           1        1  10.66  12.880        56    11.0014
# 4       1        0           1        1  10.66  12.880        56    11.0014
#
#    year  month  day  dayofweek  hour
# 0  2011      1   20          3     0
# 1  2011      1   20          3     1
# 2  2011      1   20          3     2
# 3  2011      1   20          3     3
# 4  2011      1   20          3     4

# %%
result = regressor.predict(X_test)

# %%
result[:5]
# Out:
# array([11.362558 , -0.7155521, -4.781685 , -4.620646 , -4.620646 ],
#       dtype=float32)

# %%
df_test["count"] = result

# %%
df_test.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  day  dayofweek  hour      count
# 0        56    26.0027  2011      1   20          3     0  11.362558
# 1        56     0.0000  2011      1   20          3     1  -0.715552
# 2        56     0.0000  2011      1   20          3     2  -4.781685
# 3        56    11.0014  2011      1   20          3     3  -4.620646
# 4        56    11.0014  2011      1   20          3     4  -4.620646

# %%
df_test[df_test["count"] < 0]
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 1    2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2    2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3    2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4    2011-01-20 04:00:00       1        0           1        1  10.66  12.880
# 25   2011-01-21 01:00:00       1        0           1        2   9.84  11.365
# 26   2011-01-21 02:00:00       1        0           1        3   9.84  12.120
# 27   2011-01-21 03:00:00       1        0           1        3   9.02  10.605
# 28   2011-01-21 04:00:00       1        0           1        2   9.02  12.880
# 52   2011-01-22 04:00:00       1        0           0        2   0.82   0.760
# 53   2011-01-22 06:00:00       1        0           0        2   0.82   1.515
# 54   2011-01-22 07:00:00       1        0           0        1   0.82   0.760
# 55   2011-01-22 08:00:00       1        0           0        1   0.82   0.000
# 75   2011-01-23 05:00:00       1        0           0        2   1.64   3.790
# 76   2011-01-23 06:00:00       1        0           0        2   1.64   3.790
# 77   2011-01-23 07:00:00       1        0           0        1   3.28   5.305
# 78   2011-01-23 08:00:00       1        0           0        1   2.46   3.790
# 91   2011-01-23 21:00:00       1        0           0        1   4.10   5.305
# 92   2011-01-23 22:00:00       1        0           0        1   3.28   4.545
# 93   2011-01-23 23:00:00       1        0           0        1   2.46   3.030
# 95   2011-01-24 01:00:00       1        0           1        1   1.64   2.275
# 96   2011-01-24 03:00:00       1        0           1        1   1.64   1.515
# 97   2011-01-24 04:00:00       1        0           1        1   0.82   3.030
# 53          44    15.0013  2011      1   22          5     6  -8.672499
# 54          44    19.0012  2011      1   22          5     7 -53.881767
# 55          44    22.0028  2011      1   22          5     8 -11.153736
# 75          57     7.0015  2011      1   23          6     5  -9.976609
# 76          57     7.0015  2011      1   23          6     6 -14.073925
# 77          58    11.0014  2011      1   23          6     7 -69.735794
# 78          62    11.0014  2011      1   23          6     8 -33.300716
# 91          36    12.9980  2011      1   23          6    21  -1.705025
# 92          38    12.9980  2011      1   23          6    22 -10.338671
# 93          41    15.0013  2011      1   23          6    23 -22.039064
# 95          45    12.9980  2011      1   24          0     1  -7.795416
# 96          45    16.9979  2011      1   24          0     3 -14.093010
# 97          48     8.9981  2011      1   24          0     4 -12.805416
# 98          48     8.9981  2011      1   24          0     5  -1.656461
# 118         69    11.0014  2011      1   25          1     1  -3.432286
# 119         69    15.0013  2011      1   25          1     2 -10.732008
# 120         74     7.0015  2011      1   25          1     4  -7.964006
# 141         65     8.9981  2011      1   26          2     1  -0.563373
# 142         69    12.9980  2011      1   26          2     2  -9.024894
# 143         86    19.0012  2011      1   26          2     5  -3.162729
# 148         93    19.0012  2011      1   26          2    10  -7.788037
# ...        ...        ...   ...    ...  ...        ...   ...        ...
# 4110        87    22.0028  2012      4   23          0     2  -2.768368
# 4112        81    19.0012  2012      4   23          0     4 -14.255868
# 4113        81    19.0012  2012      4   23          0     5  -3.106910
# 4324        88    19.9995  2012      5   21          0     0  -6.032341
# 4325        88    23.9994  2012      5   21          0     1 -21.722069
# 4326        94    16.9979  2012      5   21          0     2 -32.955956
# 4327        88    19.9995  2012      5   21          0     3 -13.578717
# 4328        88    19.9995  2012      5   21          0     4 -30.617228
# 4329        88    19.9995  2012      5   21          0     5 -16.507254
# 4376        83    12.9980  2012      5   23          2     4  -0.174671
# 4542        94     6.0032  2012      5   30          2     2  -2.579056
# 4543        88     8.9981  2012      5   30          2     3  -3.392518
# 4926        94     6.0032  2012      7   23          0     2  -5.742805
# 4927        94     6.0032  2012      7   23          0     3  -6.359315
# 4928        94     8.9981  2012      7   23          0     4  -6.667011
# 5144        83     6.0032  2012      8   20          0     4  -3.247004
# 5621        88     0.0000  2012      9   28          4     1  -7.112677
# 5622        88    19.9995  2012      9   28          4     2 -11.946186
# 5624        88     7.0015  2012      9   28          4     4  -6.517415
# 5906        88    23.9994  2012     10   28          6    22  -0.881252
# 5907        94    23.9994  2012     10   28          6    23 -25.095724
# 6070        47     7.0015  2012     11   25          6     6  -0.840693
# 6115        70     8.9981  2012     11   27          1     3 -23.243391
# 6116        81    12.9980  2012     11   27          1     4 -18.881332
# 6232        88    26.0027  2012     12   21          4     1  -1.214931
# 6233        94    26.0027  2012     12   21          4     2  -2.684792
# 6234        94    26.0027  2012     12   21          4     3  -3.301302
# 6372        87    19.9995  2012     12   26          2    23  -3.239484
# 6374        93    30.0026  2012     12   27          3     1  -5.708805
# 6451        52    27.9993  2012     12   30          6     6  -1.602721
#
# [221 rows x 15 columns]

# %%
df_test["count"] = df_test["count"].map(adjust_count)

# %%
df_test[['datetime','count']].to_csv('predicted_count.csv',index=False)

# %%
# RMSLE (Kaggle) Scores
# Test 1: 1.32
# Test 2 (added new feature): 0.61646
